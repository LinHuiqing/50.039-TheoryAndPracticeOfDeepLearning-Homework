# %% [markdown]
# # Homework 9 - Descriptive Notebook
#
# In this homework notebook, we will create and train our own SkipGram embedding, by using the speech from Martin Luther King in the text.text file.
#
# Get familiar with the code and write a small report (2 pages max), with answers to the questions listed at the end of the notebook.
#
# **The report must be submitted in PDF format, before April 4th, 11.59pm!**
#
# Do not forget to write your name and student ID on the report.
#
# You may also submit your own copy of the notebook along with the report. If you do so, please add your name and ID to the cell below.

# %%
# Name:
# Student ID:

# %% [markdown]
# ### Imports needed
#
# Note, we strongly advise to use a CUDA/GPU machine for this notebook.
#
# Technically, this can be done on CPU only, but it will be very slow!
#
# If you decide to use it on CPU, you might also have to change some of the .cuda() methods used on torch tensors and models in this notebook!

# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import functools
import matplotlib.pyplot as plt
CUDA = torch.cuda.is_available()

# %% [markdown]
# ### Step 1. Produce some data based on a given text for training our SkipGram model
#
# The functions below will be used to produce our dataset for training the SkipGram model.

# %%
def text_to_train(text, context_window):
    """
    This function receives the text as a list of words, in lowercase format.
    It then returns data, a list of all the possible (x,y) pairs with
    - x being the middle word of the sentence of length 2*context_window+1,
    - y being a list of 2k words, containing the k preceding words and the k
    posterior words.
    """
    
    # Get data from list of words in text, using a context window of size k = context_window
    data = []
    for i in range(context_window, len(text) - context_window):
        target = [text[i+e] for e in range(-context_window, context_window+1) if i+e != i]
        input_word = text[i]
        data.append((input_word, target))
        
    return data

# %%
def create_text():
    """
    This function loads the string of text from the text.txt file,
    and produces a list of words in string format, as variable text.
    """
    
    # Load corpus from file
    with open("./text.txt", 'r', encoding="utf8",) as f:
        corpus = f.readlines()
    f.close()
    
    # Join corpus into a single string
    text = ""
    for s in corpus:
        l = s.split()
        for s2 in l:
            # Removes all special characters from string
            s2 = ''.join(filter(str.isalnum, s2))
            s2 += ' '
            text += s2.lower()
    text = text.split()
    
    return text

# %%
text = create_text()
print(text)
# Out:
# ['i', 'am', 'happy', 'to', 'join', 'with', 'you', 'today', 'in', 'what', 'will', 'go', 'down', 'in', 'history', 'as', 'the', 'greatest', 'demonstration', 'for', 'freedom', 'in', 'the', 'history', 'of', 'our', 'nation', 'five', 'score', 'years', 'ago', 'a', 'great', 'american', 'in', 'whose', 'symbolic', 'shadow', 'we', 'stand', 'today', 'signed', 'the', 'emancipation', 'proclamation', 'this', 'momentous', 'decree', 'came', 'as', 'a', 'great', 'beacon', 'of', 'hope', 'to', 'millions', 'of', 'slaves', 'who', 'had', 'been', 'seared', 'in', 'the', 'flames', 'of', 'whithering', 'injustice', 'it', 'came', 'as', 'a', 'joyous', 'daybreak', 'to', 'end', 'the', 'long', 'night', 'of', 'their', 'captivity', 'but', 'one', 'hundred', 'years', 'later', 'the', 'colored', 'america', 'is', 'still', 'not', 'free', 'one', 'hundred', 'years', 'later', 'the', 'life', 'of', 'the', 'colored', 'american', 'is', 'still', 'sadly', 'crippled', 'by', 'the', 'manacle', 'of', 'segregation', 'and', 'the', 'chains', 'of', 'discrimination', 'one', 'hundred', 'years', 'later', 'the', 'colored', 'american', 'lives', 'on', 'a', 'lonely', 'island', 'of', 'poverty', 'in', 'the', 'midst', 'of', 'a', 'vast', 'ocean', 'of', 'material', 'prosperity', 'one', 'hundred', 'years', 'later', 'the', 'colored', 'american', 'is', 'still', 'languishing', 'in', 'the', 'corners', 'of', 'american', 'society', 'and', 'finds', 'himself', 'an', 'exile', 'in', 'his', 'own', 'land', 'so', 'we', 'have', 'come', 'here', 'today', 'to', 'dramatize', 'a', 'shameful', 'condition', 'in', 'a', 'sense', 'we', 'have', 'come', 'to', 'our', 'nations', 'capital', 'to', 'cash', 'a', 'check', 'when', 'the', 'architects', 'of', 'our', 'great', 'republic', 'wrote', 'the', 'magnificent', 'words', 'of', 'the', 'constitution', 'and', 'the', 'declaration', 'of', 'independence', 'they', 'were', 'signing', 'a', 'promissory', 'note', 'to', 'which', 'every', 'american', 'was', 'to', 'fall', 'heir', 'this', 'note', 'was', 'a', 'promise', 'that', 'all', 'men', 'yes', 'black', 'men', 'as', 'well', 'as', 'white', 'men', 'would', 'be', 'guaranteed', 'the', 'inalienable', 'rights', 'of', 'life', 'liberty', 'and', 'the', 'pursuit', 'of', 'happiness', 'it', 'is', 'obvious', 'today', 'that', 'america', 'has', 'defaulted', 'on', 'this', 'promissory', 'note', 'insofar', 'as', 'her', 'citizens', 'of', 'color', 'are', 'concerned', 'instead', 'of', 'honoring', 'this', 'sacred', 'obligation', 'america', 'has', 'given', 'its', 'colored', 'people', 'a', 'bad', 'check', 'a', 'check', 'that', 'has', 'come', 'back', 'marked', 'insufficient', 'funds', 'but', 'we', 'refuse', 'to', 'believe', 'that', 'the', 'bank', 'of', 'justice', 'is', 'bankrupt', 'we', 'refuse', 'to', 'believe', 'that', 'there', 'are', 'insufficient', 'funds', 'in', 'the', 'great', 'vaults', 'of', 'opportunity', 'of', 'this', 'nation', 'so', 'we', 'have', 'come', 'to', 'cash', 'this', 'check', 'a', 'check', 'that', 'will', 'give', 'us', 'upon', 'demand', 'the', 'riches', 'of', 'freedom', 'and', 'security', 'of', 'justice', 'we', 'have', 'also', 'come', 'to', 'his', 'hallowed', 'spot', 'to', 'remind', 'america', 'of', 'the', 'fierce', 'urgency', 'of', 'now', 'this', 'is', 'not', 'time', 'to', 'engage', 'in', 'the', 'luxury', 'of', 'cooling', 'off', 'or', 'to', 'take', 'the', 'tranquilizing', 'drug', 'of', 'gradualism', 'now', 'is', 'the', 'time', 'to', 'make', 'real', 'the', 'promise', 'of', 'democracy', 'now', 'it', 'the', 'time', 'to', 'rise', 'from', 'the', 'dark', 'and', 'desolate', 'valley', 'of', 'segregation', 'to', 'the', 'sunlit', 'path', 'of', 'racial', 'justice', 'now', 'it', 'the', 'time', 'to', 'lift', 'our', 'nation', 'from', 'the', 'quicksand', 'of', 'racial', 'injustice', 'to', 'the', 'solid', 'rock', 'of', 'brotherhood', 'now', 'is', 'the', 'time', 'to', 'make', 'justice', 'a', 'reality', 'to', 'all', 'of', 'gods', 'children', 'i', 'would', 'be', 'fatal', 'for', 'the', 'nation', 'to', 'overlook', 'the', 'urgency', 'of', 'the', 'moment', 'and', 'to' ...

# %%
def generate_data(text, context_window):
    """
    This function receives the text and context window size.
    It produces four outputs:
    - vocab, a set containing the words found in text.txt,
    without any doublons,
    - word2index, a dictionary to convert words to their integer index,
    - word2index, a dictionary to convert integer index to their respective words,
    - data, containing our (x,y) pairs for training.
    """
    
    # Create vocabulary set V
    vocab = set(text)
    
    # Word to index and index 2 word converters
    word2index = {w:i for i,w in enumerate(vocab)}
    index2word = {i:w for i,w in enumerate(vocab)}
    
    # Generate data
    data = text_to_train(text, context_window)
    
    return vocab, data, word2index, index2word

# %%
vocab, data, word2index, index2word = generate_data(text, context_window = 2)

# %%
print(vocab)
# Out:
# {'mountainside', 'emerges', 'no', 'color', 'as', 'whithering', 'gentiles', 'slaves', 'hold', 'constitution', 'this', 'white', 'americans', 'heir', 'go', 'shadow', 'autumn', 'nullification', 'state', 'beginning', 'now', 'larger', 'security', 'but', 'veterans', 'fathers', 'some', 'sacred', 'magnificent', 'real', 'satisfied', 'later', 'created', 'selfevident', 'underestimate', 'island', 'skin', 'vicious', 'needed', 'cooling', 'blow', 'made', 'were', 'judged', 'which', 'us', 'stream', 'daybreak', 'end', 'quest', 'gradualism', 'equality', 'opportunity', 'motels', 'our', 'hilltops', 'by', 'lord', 'revealed', 'he', 'heavy', 'brothers', 'emancipation', 'engage', 'snowcapped', 'areas', 'signing', 'old', 'their', 'only', 'character', 'rough', 'freedom', 'deeply', 'discords', 'republic', 'lives', 'happiness', 'score', 'staggered', 'stone', 'interposition', 'given', 'unmindful', 'sunlit', 'peoples', 'whirlwinds', 'rolls', 'on', 'i', 'defaulted', 'today', 'demonstration', 'stripped', 'determination', 'rise', 'left', 'who', 'seared', 'persons', 'captivity', 'proclamation', 'bad', 'spot', 'an', 'brotherhood', 'difficulties', 'engulfed', 'redemptive', 'independence', 'lips', 'trials', 'material', 'creed', 'can', 'when', 'pursuit', 'beacon', 'york', 'my', 'vaults', 'insufficient', 'nation', 'sweet', 'we', 'every', 'be', 'hills', 'suffering', 'bankrupt', 'fatigue', 'summer', 'continue', 'able', 'city', 'sisters', 'transformed', 'wallow', 'sit', 'slaveowners', 'if', 'mississippi', 'make', 'great', 'honoring', 'and', 'hands', 'fall', 'long', 'battered', 'molehill', 'believes', 'quicksand', 'creative', 'dripping', 'chains', 'straight', 'justice', 'momentous', 'situation', 'until', 'would', 'shall', 'exalted', 'fatal', 'lodging', 'gain', 'stating', 'carolina', 'up', 'citizen', 'crooked', 'thank', 'its', 'alleghenies', 'cannot', 'will', 'awakening', 'brutality', 'been', 'hope', 'say', 'manacle', 'foundations', 'tis', 'here', 'places', 'free', 'american', 'or', 'jangling', 'well', 'nothing', 'flesh', 'decree', 'pass', 'having', 'must', 'happy', 'years', 'words', 'take', 'oasis', 'sweltering', 'believe', 'travel', 'bank', 'not', 'ring', 'have', 'symbolic', 'persecutions', 'give', 'there', 'hamlet', 'shake', 'plains', 'curvaceous', 'poverty', 'land', 'reality', 'citizenship', 'symphony', 'equal', 'life', 'these', 'little', 'where', 'content', 'live', 'died', 'time', 'instead', 'rest', 'children', 'boys', 'joyous', 'rock', 'solid', 'dark', 'millions', 'the', 'never', 'mountain', 'guaranteed', 'drug', 'nor', 'signs', 'sadly', 'desolate', 'demand', 'with', 'hew', 'california', 'into', 'yes', 'join', 'architects', 'her', 'to', 'cash', 'governor', 'catholics', 'new', 'storms', 'declaration', 'down', 'history', 'last', 'colorado', 'tranquility', 'they', 'faith', 'you', 'refuse', 'inalienable', 'former', 'righteousness', 'usual', 'was', 'concerned', 'alabama', 'see', 'it', 'democracy', 'is', 'day', 'night', 'table', 'men', 'bright', 'winds', 'thee', 'meaning', 'dramatize', 'sixtythree', 'in', 'languishing', 'almighty', 'mobility', 'from', 'low', 'nations', 'pray', 'gods', 'has', 'tomorrow', 'crippled', 'corners', 'discontent', 'returns', 'fierce', 'people', 'ocean', 'ago', 'note', 'dream', 'pilgrims', 'true', 'transform', 'finds', 'sense', 'luxury', 'valley', 'condition', 'his', 'insofar', 'what', 'whose', 'ghettos', 'knowing', 'neither', 'four', 'slums', 'racial', 'revolt', 'racists', 'hampshire', 'heat', 'country', 'remind', 'funds', 'upon', 'pennsylvania', 'a', 'urgency', 'work', 'nineteen', 'five', 'despair', 'hundred', 'that', 'slopes', 'become', 'capital', 'police', 'business', 'struggle', 'own', 'himself', 'obvious', 'person', 'so', 'rockies', 'selfhood', 'lonely', 'path', 'pride', 'promise', 'all', 'of', 'tribulations', 'vast', 'flames', 'robbed', 'truths', 'citizens', 'tenement', 'signed', 'girls', 'back', 'wrote', 'god', 'riches', 'ghetto', 'changed', 'right', 'oppression', 'like', 'mountains', 'out', 'black', 'friends', 'invigorating', 'modern', 'o ...

# %%
print(word2index)
# Out:
# {'mountainside': 0, 'emerges': 1, 'no': 2, 'color': 3, 'as': 4, 'whithering': 5, 'gentiles': 6, 'slaves': 7, 'hold': 8, 'constitution': 9, 'this': 10, 'white': 11, 'americans': 12, 'heir': 13, 'go': 14, 'shadow': 15, 'autumn': 16, 'nullification': 17, 'state': 18, 'beginning': 19, 'now': 20, 'larger': 21, 'security': 22, 'but': 23, 'veterans': 24, 'fathers': 25, 'some': 26, 'sacred': 27, 'magnificent': 28, 'real': 29, 'satisfied': 30, 'later': 31, 'created': 32, 'selfevident': 33, 'underestimate': 34, 'island': 35, 'skin': 36, 'vicious': 37, 'needed': 38, 'cooling': 39, 'blow': 40, 'made': 41, 'were': 42, 'judged': 43, 'which': 44, 'us': 45, 'stream': 46, 'daybreak': 47, 'end': 48, 'quest': 49, 'gradualism': 50, 'equality': 51, 'opportunity': 52, 'motels': 53, 'our': 54, 'hilltops': 55, 'by': 56, 'lord': 57, 'revealed': 58, 'he': 59, 'heavy': 60, 'brothers': 61, 'emancipation': 62, 'engage': 63, 'snowcapped': 64, 'areas': 65, 'signing': 66, 'old': 67, 'their': 68, 'only': 69, 'character': 70, 'rough': 71, 'freedom': 72, 'deeply': 73, 'discords': 74, 'republic': 75, 'lives': 76, 'happiness': 77, 'score': 78, 'staggered': 79, 'stone': 80, 'interposition': 81, 'given': 82, 'unmindful': 83, 'sunlit': 84, 'peoples': 85, 'whirlwinds': 86, 'rolls': 87, 'on': 88, 'i': 89, 'defaulted': 90, 'today': 91, 'demonstration': 92, 'stripped': 93, 'determination': 94, 'rise': 95, 'left': 96, 'who': 97, 'seared': 98, 'persons': 99, 'captivity': 100, 'proclamation': 101, 'bad': 102, 'spot': 103, 'an': 104, 'brotherhood': 105, 'difficulties': 106, 'engulfed': 107, 'redemptive': 108, 'independence': 109, 'lips': 110, 'trials': 111, 'material': 112, 'creed': 113, 'can': 114, 'when': 115, 'pursuit': 116, 'beacon': 117, 'york': 118, 'my': 119, 'vaults': 120, 'insufficient': 121, 'nation': 122, 'sweet': 123, 'we': 124, 'every': 125, 'be': 126, 'hills': 127, 'suffering': 128, 'bankrupt': 129, 'fatigue': 130, 'summer': 131, 'continue': 132, 'able': 133, 'city': 134, 'sisters': 135, 'transformed': 136, 'wallow': 137, 'sit': 138, 'slaveowners': 139, 'if': 140, 'mississippi': 141, 'make': 142, 'great': 143, 'honoring': 144, 'and': 145, 'hands': 146, 'fall': 147, 'long': 148, 'battered': 149, 'molehill': 150, 'believes': 151, 'quicksand': 152, 'creative': 153, 'dripping': 154, 'chains': 155, 'straight': 156, 'justice': 157, 'momentous': 158, 'situation': 159, 'until': 160, 'would': 161, 'shall': 162, 'exalted': 163, 'fatal': 164, 'lodging': 165, 'gain': 166, 'stating': 167, 'carolina': 168, 'up': 169, 'citizen': 170, 'crooked': 171, 'thank': 172, 'its': 173, 'alleghenies': 174, 'cannot': 175, 'will': 176, 'awakening': 177, 'brutality': 178, 'been': 179, 'hope': 180, 'say': 181, 'manacle': 182, 'foundations': 183, 'tis': 184, 'here': 185, 'places': 186, 'free': 187, 'american': 188, 'or': 189, 'jangling': 190, 'well': 191, 'nothing': 192, 'flesh': 193, 'decree': 194, 'pass': 195, 'having': 196, 'must': 197, 'happy': 198, 'years': 199, 'words': 200, 'take': 201, 'oasis': 202, 'sweltering': 203, 'believe': 204, 'travel': 205, 'bank': 206, 'not': 207, 'ring': 208, 'have': 209, 'symbolic': 210, 'persecutions': 211, 'give': 212, 'there': 213, 'hamlet': 214, 'shake': 215, 'plains': 216, 'curvaceous': 217, 'poverty': 218, 'land': 219, 'reality': 220, 'citizenship': 221, 'symphony': 222, 'equal': 223, 'life': 224, 'these': 225, 'little': 226, 'where': 227, 'content': 228, 'live': 229, 'died': 230, 'time': 231, 'instead': 232, 'rest': 233, 'children': 234, 'boys': 235, 'joyous': 236, 'rock': 237, 'solid': 238, 'dark': 239, 'millions': 240, 'the': 241, 'never': 242, 'mountain': 243, 'guaranteed': 244, 'drug': 245, 'nor': 246, 'signs': 247, 'sadly': 248, 'desolate': 249, 'demand': 250, 'with': 251, 'hew': 252, 'california': 253, 'into': 254, 'yes': 255, 'join': 256, 'architects': 257, 'her': 258, 'to': 259, 'cash': 260, 'governor': 261, 'catholics': 262, 'new': 263, 'storms': 264, 'declaration': 265, 'down': 266, 'history': 267, 'last': 268, 'colorado': 269, 'tranquilit ...

# %%
print(index2word)
# Out:
# {0: 'mountainside', 1: 'emerges', 2: 'no', 3: 'color', 4: 'as', 5: 'whithering', 6: 'gentiles', 7: 'slaves', 8: 'hold', 9: 'constitution', 10: 'this', 11: 'white', 12: 'americans', 13: 'heir', 14: 'go', 15: 'shadow', 16: 'autumn', 17: 'nullification', 18: 'state', 19: 'beginning', 20: 'now', 21: 'larger', 22: 'security', 23: 'but', 24: 'veterans', 25: 'fathers', 26: 'some', 27: 'sacred', 28: 'magnificent', 29: 'real', 30: 'satisfied', 31: 'later', 32: 'created', 33: 'selfevident', 34: 'underestimate', 35: 'island', 36: 'skin', 37: 'vicious', 38: 'needed', 39: 'cooling', 40: 'blow', 41: 'made', 42: 'were', 43: 'judged', 44: 'which', 45: 'us', 46: 'stream', 47: 'daybreak', 48: 'end', 49: 'quest', 50: 'gradualism', 51: 'equality', 52: 'opportunity', 53: 'motels', 54: 'our', 55: 'hilltops', 56: 'by', 57: 'lord', 58: 'revealed', 59: 'he', 60: 'heavy', 61: 'brothers', 62: 'emancipation', 63: 'engage', 64: 'snowcapped', 65: 'areas', 66: 'signing', 67: 'old', 68: 'their', 69: 'only', 70: 'character', 71: 'rough', 72: 'freedom', 73: 'deeply', 74: 'discords', 75: 'republic', 76: 'lives', 77: 'happiness', 78: 'score', 79: 'staggered', 80: 'stone', 81: 'interposition', 82: 'given', 83: 'unmindful', 84: 'sunlit', 85: 'peoples', 86: 'whirlwinds', 87: 'rolls', 88: 'on', 89: 'i', 90: 'defaulted', 91: 'today', 92: 'demonstration', 93: 'stripped', 94: 'determination', 95: 'rise', 96: 'left', 97: 'who', 98: 'seared', 99: 'persons', 100: 'captivity', 101: 'proclamation', 102: 'bad', 103: 'spot', 104: 'an', 105: 'brotherhood', 106: 'difficulties', 107: 'engulfed', 108: 'redemptive', 109: 'independence', 110: 'lips', 111: 'trials', 112: 'material', 113: 'creed', 114: 'can', 115: 'when', 116: 'pursuit', 117: 'beacon', 118: 'york', 119: 'my', 120: 'vaults', 121: 'insufficient', 122: 'nation', 123: 'sweet', 124: 'we', 125: 'every', 126: 'be', 127: 'hills', 128: 'suffering', 129: 'bankrupt', 130: 'fatigue', 131: 'summer', 132: 'continue', 133: 'able', 134: 'city', 135: 'sisters', 136: 'transformed', 137: 'wallow', 138: 'sit', 139: 'slaveowners', 140: 'if', 141: 'mississippi', 142: 'make', 143: 'great', 144: 'honoring', 145: 'and', 146: 'hands', 147: 'fall', 148: 'long', 149: 'battered', 150: 'molehill', 151: 'believes', 152: 'quicksand', 153: 'creative', 154: 'dripping', 155: 'chains', 156: 'straight', 157: 'justice', 158: 'momentous', 159: 'situation', 160: 'until', 161: 'would', 162: 'shall', 163: 'exalted', 164: 'fatal', 165: 'lodging', 166: 'gain', 167: 'stating', 168: 'carolina', 169: 'up', 170: 'citizen', 171: 'crooked', 172: 'thank', 173: 'its', 174: 'alleghenies', 175: 'cannot', 176: 'will', 177: 'awakening', 178: 'brutality', 179: 'been', 180: 'hope', 181: 'say', 182: 'manacle', 183: 'foundations', 184: 'tis', 185: 'here', 186: 'places', 187: 'free', 188: 'american', 189: 'or', 190: 'jangling', 191: 'well', 192: 'nothing', 193: 'flesh', 194: 'decree', 195: 'pass', 196: 'having', 197: 'must', 198: 'happy', 199: 'years', 200: 'words', 201: 'take', 202: 'oasis', 203: 'sweltering', 204: 'believe', 205: 'travel', 206: 'bank', 207: 'not', 208: 'ring', 209: 'have', 210: 'symbolic', 211: 'persecutions', 212: 'give', 213: 'there', 214: 'hamlet', 215: 'shake', 216: 'plains', 217: 'curvaceous', 218: 'poverty', 219: 'land', 220: 'reality', 221: 'citizenship', 222: 'symphony', 223: 'equal', 224: 'life', 225: 'these', 226: 'little', 227: 'where', 228: 'content', 229: 'live', 230: 'died', 231: 'time', 232: 'instead', 233: 'rest', 234: 'children', 235: 'boys', 236: 'joyous', 237: 'rock', 238: 'solid', 239: 'dark', 240: 'millions', 241: 'the', 242: 'never', 243: 'mountain', 244: 'guaranteed', 245: 'drug', 246: 'nor', 247: 'signs', 248: 'sadly', 249: 'desolate', 250: 'demand', 251: 'with', 252: 'hew', 253: 'california', 254: 'into', 255: 'yes', 256: 'join', 257: 'architects', 258: 'her', 259: 'to', 260: 'cash', 261: 'governor', 262: 'catholics', 263: 'new', 264: 'storms', 265: 'declaration', 266: 'down', 267: 'history', 268: 'last', 269: 'colorado', 270: 'tranq ...

# %%
print(data)
# Out:
# [('happy', ['i', 'am', 'to', 'join']), ('to', ['am', 'happy', 'join', 'with']), ('join', ['happy', 'to', 'with', 'you']), ('with', ['to', 'join', 'you', 'today']), ('you', ['join', 'with', 'today', 'in']), ('today', ['with', 'you', 'in', 'what']), ('in', ['you', 'today', 'what', 'will']), ('what', ['today', 'in', 'will', 'go']), ('will', ['in', 'what', 'go', 'down']), ('go', ['what', 'will', 'down', 'in']), ('down', ['will', 'go', 'in', 'history']), ('in', ['go', 'down', 'history', 'as']), ('history', ['down', 'in', 'as', 'the']), ('as', ['in', 'history', 'the', 'greatest']), ('the', ['history', 'as', 'greatest', 'demonstration']), ('greatest', ['as', 'the', 'demonstration', 'for']), ('demonstration', ['the', 'greatest', 'for', 'freedom']), ('for', ['greatest', 'demonstration', 'freedom', 'in']), ('freedom', ['demonstration', 'for', 'in', 'the']), ('in', ['for', 'freedom', 'the', 'history']), ('the', ['freedom', 'in', 'history', 'of']), ('history', ['in', 'the', 'of', 'our']), ('of', ['the', 'history', 'our', 'nation']), ('our', ['history', 'of', 'nation', 'five']), ('nation', ['of', 'our', 'five', 'score']), ('five', ['our', 'nation', 'score', 'years']), ('score', ['nation', 'five', 'years', 'ago']), ('years', ['five', 'score', 'ago', 'a']), ('ago', ['score', 'years', 'a', 'great']), ('a', ['years', 'ago', 'great', 'american']), ('great', ['ago', 'a', 'american', 'in']), ('american', ['a', 'great', 'in', 'whose']), ('in', ['great', 'american', 'whose', 'symbolic']), ('whose', ['american', 'in', 'symbolic', 'shadow']), ('symbolic', ['in', 'whose', 'shadow', 'we']), ('shadow', ['whose', 'symbolic', 'we', 'stand']), ('we', ['symbolic', 'shadow', 'stand', 'today']), ('stand', ['shadow', 'we', 'today', 'signed']), ('today', ['we', 'stand', 'signed', 'the']), ('signed', ['stand', 'today', 'the', 'emancipation']), ('the', ['today', 'signed', 'emancipation', 'proclamation']), ('emancipation', ['signed', 'the', 'proclamation', 'this']), ('proclamation', ['the', 'emancipation', 'this', 'momentous']), ('this', ['emancipation', 'proclamation', 'momentous', 'decree']), ('momentous', ['proclamation', 'this', 'decree', 'came']), ('decree', ['this', 'momentous', 'came', 'as']), ('came', ['momentous', 'decree', 'as', 'a']), ('as', ['decree', 'came', 'a', 'great']), ('a', ['came', 'as', 'great', 'beacon']), ('great', ['as', 'a', 'beacon', 'of']), ('beacon', ['a', 'great', 'of', 'hope']), ('of', ['great', 'beacon', 'hope', 'to']), ('hope', ['beacon', 'of', 'to', 'millions']), ('to', ['of', 'hope', 'millions', 'of']), ('millions', ['hope', 'to', 'of', 'slaves']), ('of', ['to', 'millions', 'slaves', 'who']), ('slaves', ['millions', 'of', 'who', 'had']), ('who', ['of', 'slaves', 'had', 'been']), ('had', ['slaves', 'who', 'been', 'seared']), ('been', ['who', 'had', 'seared', 'in']), ('seared', ['had', 'been', 'in', 'the']), ('in', ['been', 'seared', 'the', 'flames']), ('the', ['seared', 'in', 'flames', 'of']), ('flames', ['in', 'the', 'of', 'whithering']), ('of', ['the', 'flames', 'whithering', 'injustice']), ('whithering', ['flames', 'of', 'injustice', 'it']), ('injustice', ['of', 'whithering', 'it', 'came']), ('it', ['whithering', 'injustice', 'came', 'as']), ('came', ['injustice', 'it', 'as', 'a']), ('as', ['it', 'came', 'a', 'joyous']), ('a', ['came', 'as', 'joyous', 'daybreak']), ('joyous', ['as', 'a', 'daybreak', 'to']), ('daybreak', ['a', 'joyous', 'to', 'end']), ('to', ['joyous', 'daybreak', 'end', 'the']), ('end', ['daybreak', 'to', 'the', 'long']), ('the', ['to', 'end', 'long', 'night']), ('long', ['end', 'the', 'night', 'of']), ('night', ['the', 'long', 'of', 'their']), ('of', ['long', 'night', 'their', 'captivity']), ('their', ['night', 'of', 'captivity', 'but']), ('captivity', ['of', 'their', 'but', 'one']), ('but', ['their', 'captivity', 'one', 'hundred']), ('one', ['captivity', 'but', 'hundred', 'years']), ('hundred', ['but', 'one', 'years', 'later']), ('years', ['one', 'hundred', 'later', 'the']), ('later', ['hundred', 'years', 'the ...

# %%
def words_to_tensor(words: list, word2index: dict, dtype = torch.FloatTensor):
    """
    This fucntion converts a word or a list of words into a torch tensor,
    with appropriate format.
    It reuses the word2index dictionary.
    """
    
    tensor =  dtype([word2index[word] for word in words])
    tensor = tensor.cuda()
    
    return Variable(tensor)

# %% [markdown]
# ### Step 2. Create a SkipGram model and train
#
# Task #1: Write your own model for the SkipGram model below.

# %%
class SkipGram(nn.Module):
    """
    Your skipgram model here!
    """
    
    def __init__(self, context_size, embedding_dim, vocab_size):
        pass

    def forward(self, inputs):
        pass

# %%
# Create model and pass to CUDA
model = SkipGram(context_size = 2, embedding_dim = 20, vocab_size = len(vocab))
model = model.cuda()
model.train()

# %%
# Define training parameters
learning_rate = 0.001
epochs = 50
torch.manual_seed(28)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr = learning_rate)

# %%
def get_prediction(context, model, word2index, index2word):
    """
    This is a helper function to get prediction from our model.
    """
    
    return None

# %% [markdown]
# Task #2: Write your own training function for the SkipGram model in the cell below. It should return a list of losses and accuracies for display later on, along with your trained model. You may also write a helper function for computing the accuracy of your model during training.

# %%
def train(data, word2index, model, epochs, loss_func, optimizer):
    losses = []
    accuracies = []
    pass
    return losses, accuracies, model

losses, accuracies, model = train(data, word2index, model, epochs, loss_func, optimizer)

# %% [markdown]
# ### 3. Visualization

# %%
# Display losses over time
plt.figure()
plt.plot(losses)
plt.show()

# %%
# Display accuracies over time
plt.figure()
plt.plot(accuracies)
plt.show()

# %% [markdown]
# ### Questions and expected answers for the report
#
# A. Copy and paste your SkipGram class code (Task #1 in the notebook)
#
# B. Copy and paste your train function (Task #2 in the notebook), along with any helper functions you might have used (e.g. a function to compute the accuracy of your model after each iteration). Please also copy and paste the function call with the parameters you used for the train() function.
#
# C. Why is the SkipGram model much more difficult to train than the CBoW. Is it problematic if it does not reach a 100% accuracy on the task it is being trained on?
#
# D. If we were to evaluate this model by using intrinsic methods, what could be a possible approach to do so. Please submit some code that will demonstrate the performance/problems of the word embedding you have trained!
